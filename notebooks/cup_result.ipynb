# %%
import sys
sys.path.append('..')

import pandas as pd
from src.utils import parse_results

# %%
res2416 = pd.read_csv("./results2416.csv")
res3216 = pd.read_csv("./results3216.csv")

res2416.sort_values(by=['accuracy'], ascending=True)
# Out:
#       eta  nesterov reg_type       reg_val  accuracy      loss   val_loss
# 33  0.010       0.6       L2  1.000000e-08  1.518496  0.004098   1.932224
# 5   0.010       0.8       L1  1.000000e-08  1.526607  0.003969   1.927129
# 25  0.010       0.5       L2  1.000000e-08  1.527799  0.004136   1.940701
# 28  0.010       0.5       L1  1.000000e-07  1.528174  0.004240   1.929012
# 21  0.010       0.7       L1  1.000000e-08  1.528464  0.004145   1.940864
# ..    ...       ...      ...           ...       ...       ...        ...
# 78  0.001       0.6       L1  1.000000e-06  7.240886  0.065246  29.896245
# 63  0.001       0.7       L1  1.000000e-05  7.240980  0.065246  29.895775
# 47  0.001       0.8       L1  1.000000e-05  7.241163  0.065247  29.895911
# 67  0.001       0.5       L2  1.000000e-05  7.243679  0.065237  29.890249
# 62  0.001       0.7       L1  1.000000e-06  7.244614  0.065243  29.893193
#
# [120 rows x 7 columns]

# %%
res3216.sort_values(by=['accuracy'], ascending=True)
# Out:
#       eta  nesterov reg_type       reg_val  accuracy      loss   val_loss
# 36  0.010       0.6       L1  1.000000e-07  1.516977  0.003936   1.907787
# 21  0.010       0.7       L1  1.000000e-08  1.520069  0.003872   1.898781
# 5   0.010       0.8       L1  1.000000e-08  1.523364  0.003800   1.884325
# 32  0.010       0.6       L2  1.000000e-07  1.523855  0.003699   1.917247
# 99  0.100       0.7       L2  1.000000e-05  1.524869  0.003758   1.890357
# ..    ...       ...      ...           ...       ...       ...        ...
# 79  0.001       0.6       L1  1.000000e-05  7.240312  0.065245  29.895940
# 55  0.001       0.9       L1  1.000000e-05  7.240577  0.065246  29.895930
# 78  0.001       0.6       L1  1.000000e-06  7.240586  0.065246  29.896241
# 47  0.001       0.8       L1  1.000000e-05  7.240609  0.065246  29.895976
# 62  0.001       0.7       L1  1.000000e-06  7.243286  0.065248  29.894284
#
# [120 rows x 7 columns]
